# %% [markdown]
# # ETL Operations

# %%
import scipy, os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %%
#Read the raw datasets

basedir = 'C:/Users/Traian Fulea/Desktop/Final Assessment/Data/'
df15 = pd.read_excel(os.path.join(basedir, '2015.xls'), sheet_name = 'FEguide')
df16 = pd.read_excel(os.path.join(basedir, '2016.xlsx'), sheet_name = 'FEguide')
df17 = pd.read_excel(os.path.join(basedir, '2017.xlsx'), sheet_name = 'FEguide')
df18 = pd.read_excel(os.path.join(basedir, '2018.xlsx'), sheet_name = 'FEguide')
df19 = pd.read_excel(os.path.join(basedir, '2019.xlsx'), sheet_name = '2019 FEguide')
df20 = pd.read_excel(os.path.join(basedir, '2020.xlsx'), sheet_name = '20')
df21 = pd.read_excel(os.path.join(basedir, '2021.xlsx'), sheet_name = '21')
df22 = pd.read_excel(os.path.join(basedir, '2022.xlsx'), sheet_name = '22')

frames = [df15, df16, df17, df18, df19, df20, df21, df22]

# %%
#Display some info about the 2015 datasets

df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 729 entries, 0 to 728
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Model Year                729 non-null    int64
#  1   Mfr Name                  729 non-null    object
#  2   Division                  729 non-null    object
#  3   Carline                   729 non-null    object
#  4   Engine Displacement       729 non-null    float64
#  5   # Cylinders               729 non-null    int64
#  6   Transmission              729 non-null    object
#  7   City FE                   729 non-null    int64
#  8   Highway FE                729 non-null    int64
#  9   Combined FE               729 non-null    int64
#  10  Air Aspiration Method     729 non-null    object
#  11  Transmission Description  729 non-null    object
#  12  # Gears                   729 non-null    int64
#  13  Drive Desc                729 non-null    object
#  14  Carline Class Desc        729 non-null    object
#  15  Release Date              729 non-null    datetime64[ns]
#  16  City CO2                  729 non-null    int64
#  17  Highway CO2               729 non-null    int64
#  18  Combined CO2              729 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(9), object(8)
# memory usage: 108.3+ KB

# %%
df16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1213 entries, 0 to 1212
# Columns: 162 entries, Model Year to Comb PHEV Composite MPGe
# dtypes: datetime64[ns](1), float64(72), int64(16), object(73)
# memory usage: 1.5+ MB

# %% [markdown]
# ## 1. Column matching and renaming

# %%
columns = df15.columns.tolist()
print(columns)
print(len(columns))
# Out:
# ['Model Year', 'Mfr Name', 'Division', 'Carline', 'Engine Displacement', '# Cylinders', 'Transmission', 'City FE', 'Highway FE', 'Combined FE', 'Air Aspiration Method', 'Transmission Description', '# Gears', 'Drive Desc', 'Carline Class Desc', 'Release Date', 'City CO2', 'Highway CO2', 'Combined CO2']
# 19

# %%
#Visualize the common columns

for i in df15.columns.tolist():
    if i in df16.columns.tolist():
        print(i)
# Out:
# Model Year
# Mfr Name
# Division
# Carline
# Transmission
# # Gears
# Drive Desc
# Carline Class Desc
# Release Date

# %%
#Visualize the column names between the previous datasets

distinct = list()
same = list()
remained = columns.copy()
for i in df16.columns.tolist():
    if i not in columns:
        distinct.append(i)
    else:
        same.append(i)
        remained.remove(i)

print("Distinct column names: \n", distinct)

print("Columns that need to be found names: \n", remained)
# Out:
# Distinct column names:
#  ['Verify Mfr Cd', 'Index (Model Type Index)', 'Eng Displ', '# Cyl', 'City FE (Guide) - Conventional Fuel', 'Hwy FE (Guide) - Conventional Fuel', 'Comb FE (Guide) - Conventional Fuel', 'City Unadj FE - Conventional Fuel', 'Hwy Unadj FE - Conventional Fuel', 'Comb Unadj FE - Conventional Fuel', 'City Unrd Adj FE - Conventional Fuel', 'Hwy Unrd Adj FE - Conventional Fuel', 'Comb Unrd Adj FE - Conventional Fuel', 'Guzzler? ', 'Air Aspir Method', 'Air Aspiration Method Desc', 'Trans', 'Trans Desc', 'Trans, Other', 'Lockup Torque Converter', 'Trans Creeper Gear', 'Drive Sys', 'Max Ethanol % - Gasoline', 'Max Biodiesel %', 'Range1 - Model Type Driving Range - Conventional Fuel', 'Fuel Usage  - Conventional Fuel', 'Fuel Usage Desc - Conventional Fuel', 'Fuel Unit - Conventional Fuel', 'Fuel Unit Desc - Conventional Fuel', 'Gas Guzzler Exempt (Where Truck = 1975 NHTSA truck definition)', 'Gas Guzzler Exempt Desc (Where Truck = 1975 NHTSA truck definition)', '2Dr Pass Vol', '2Dr Lugg Vol', '4Dr Pass Vol', '4Dr Lugg Vol', 'Htchbk Pass Vol', 'Htchbk Lugg Vol', 'Annual Fuel1 Cost - Conventional Fuel', 'EPA Calculated Annual Fuel Cost - Conventional Fuel -----  Annual fuel cost error. Please revise Verify. ', 'City2 FE (Guide) - Alternative Fuel', 'Hwy2 Fuel FE (Guide) - Alternative Fuel', 'Comb2 Fuel FE (Guide) - Alternative Fuel', 'City2 Unadj FE - Alternative Fuel', 'Hwy2 Unadj FE - Alternative Fuel', 'Comb2 Unadj FE - Alternative Fuel', 'City2 Unrd Adj FE - Alternative Fuel', 'Hwy2 Unrd Adj FE - Alternative Fuel', 'Cmb2 Unrd Adj FE - Alternative Fuel', ' Range2 - Alt Fuel Model Typ Driving Range - Alternative Fuel', ' Fuel2 Usage - Alternative Fuel', ' Fuel2 Usage Desc - Alternative Fuel', 'Fuel2 Unit - Alternative Fuel', 'Fuel2 Unit Desc - Alternative Fuel', 'Fuel2 Annual Fuel Cost - Alternative Fuel', 'City CO2 Rounded Adjusted - Fuel2', 'Hwy CO2 Rounded Adjusted - Fuel2', 'Comb CO2 Rounded Adjusted - Fuel2', 'Fuel2 EPA Calculated Annual Fuel Cost - Alternative Fuel', 'Descriptor - Model Type (40 Char or less)', 'Intake Valves Per Cyl', 'Exhaust Valves Per Cyl', 'Carline Class', 'Car/Truck Category - Cash for Clunkers Bill.', 'Calc Approach Desc', 'EPA FE Label Dataset ID', 'Unnamed: 74', 'Unique Label?', 'Label Recalc?', 'Relabel', 'Relabel Desc', 'Suppressed?', 'Police/Emerg?', 'Comments - Mfr Eng Cnfg', 'Cyl Deact?', 'Cyl Deact Desc', 'Var Valve Timing?', 'Var Valve Timing Desc', 'Var Valve Lift?', 'Var Valve Lift Desc', 'Energy Storage Device Desc', 'Energy Storage Device,If Other', '# Batteries', 'Battery Type Desc', 'Battery Type, If Other', 'Total Voltage for Battery Pack(s)', 'Batt Energy Capacity (Amp-hrs)', 'Batt Specific Energy (Watt-hr/kg)', 'Batt Charger Type Desc', 'Comments', '# Capacitors', 'Regen Braking Type Desc', 'Regen Braking Type, If Other', 'Regen Braking Wheels Source (Front, Rear, Both)', 'Driver Cntrl Regen Braking?', 'Fuel Cell Desc', 'Usable H2 Fill Capacity (kg)', 'Fuel Cell Onboard H2 Capacity (kg)', 'HEV-EV Comments', '# Drive Motor Gen', 'Motor Gen Type Desc', 'Motor Gen Type, If Other', 'Rated Motor Gen Power (kW)', 'Fuel Metering Type 1 Desc', 'Fuel Metering Type 2 Desc', 'Fuel Metering Sys Cd', 'Fuel Metering Sys Desc', 'Fuel Cell Vehicle (Y or N)', 'Off Board Charge Capable (Y or N)', 'Camless Valvetrain (Y or N)', 'Oil Viscosity', 'Stop/Start System (Engine Management System) Code', 'Stop/Start System (Engine Management System)  Description', 'Model Type Desc (MFR entered)', 'Charge Depleting Calc Appr Code (PHEV only)', 'Charge Depleting Calc Appr Desc (PHEV only)', 'Charge Sustaining Calc Appr Code (PHEV only)', 'Charge Sustaining Calc Appr Desc (PHEV only)', 'EPA Calculated Annual Fuel Cost', 'EPA Calculated Gas Guzzler MPG', 'MFR Calculated Gas Guzzler MPG ', 'EPA Calculated Gas Guzzler Indicator (Y or N)', 'Unnamed: 130', 'FE Rating (1-10 rating on Label)', 'GHG Rating (1-10 rating on Label)', 'GHG 1-10 rating on Ethanol (EPA Determined)', '#1 Smog Rating Test Group', '#1 Mfr Smog Rating (Mf ...
# Columns that need to be found names:
#  ['Engine Displacement', '# Cylinders', 'City FE', 'Highway FE', 'Combined FE', 'Air Aspiration Method', 'Transmission Description', 'City CO2', 'Highway CO2', 'Combined CO2']

# %%
#Rename the columns so they can match with previous datasets

for i in frames:
    if i is not df15:
        i.rename(columns = {'Eng Displ' : 'Engine Displacement',
                            '# Cyl' : '# Cylinders',
                            'City FE (Guide) - Conventional Fuel' : 'City FE',
                            'Hwy FE (Guide) - Conventional Fuel' : 'Highway FE',
                            'Comb FE (Guide) - Conventional Fuel' : 'Combined FE',
                            'Air Aspir Method' : 'Air Aspiration Method',
                            'Trans Desc' : 'Transmission Description',
                            'City CO2 Rounded Adjusted' : 'City CO2',
                            'Hwy CO2 Rounded Adjusted' : 'Highway CO2',
                            'Comb CO2 Rounded Adjusted (as shown on FE Label)' : 'Combined CO2'}, inplace = True)

# %%
df22
# Out:
#       Model Year             Mfr Name                          Division  \
# 0           2022                Honda                             Acura
# 1           2022         aston martin          Aston Martin Lagonda Ltd
# 2           2022  Volkswagen Group of                              Audi
# 3           2022  Volkswagen Group of                              Audi
# 4           2022  Volkswagen Group of                              Audi
# ...          ...                  ...                               ...
# 1146        2022               Toyota                            TOYOTA
# 1147        2022               Toyota                            TOYOTA
# 1148        2022               Toyota                            TOYOTA
# 1149        2022                Volvo  Volvo Cars of North America, LLC
# 1150        2022                Volvo  Volvo Cars of North America, LLC
#
#                              Carline Verify Mfr Cd  Index (Model Type Index)  \
# 0                                NSX           HNX                       521
# 1                         Vantage V8           ASX                         4
# 2                           R8 Coupe           VGA                        14
# 3                       R8 Coupe RWD           VGA                        16
# 4                          R8 Spyder           VGA                        15
# ...                              ...           ...                       ...
# 1146           HIGHLANDER HYBRID AWD           TYX                       110
# 1147  HIGHLANDER HYBRID AWD LTD/PLAT           TYX                       105
# 1148                     SEQUOIA 4WD           TYX                        97
# 1149                     XC90 T5 AWD           VVX                       229
# 1150                     XC90 T6 AWD           VVX                       230
#
#       Engine Displacement  # Cylinders Transmission  City FE  ...  City CO2  \
# 0                     3.5            6  Auto(AM-S9)       21  ...       420
# 1                     4.0            8     Auto(A8)       18  ...       494
# 2                     5.2           10  Auto(AM-S7)       13  ...       670
# 3                     5.2           10  Auto(AM-S7)       14  ...       627
# 4                     5.2           10  Auto(AM-S7)       13  ...       670
# ...                   ...          ...          ...      ...  ...       ...
# 1146                  2.5            4  Auto(AV-S6)       35  ...       252
# 1147                  2.5            4  Auto(AV-S6)       35  ...       248
# 1148                  5.7            8     Auto(S6)       13  ...       697
# 1149                  2.0            4     Auto(S8)       20  ...       433
# 1150                  2.0            4     Auto(S8)       19  ...       464
#
#       Highway CO2  Combined CO2  \
# 0             406           420
# 1             364           435
# 2             453           572
# 3             385           518
# 4             453           572
# ...           ...           ...
# 1146          256           254
# 1147          259           253
# 1148          522           618
# 1149          314           380
# 1150          333           405
#
#       CO2-PHEV Composite Rounded Adjusted Combined CO2  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ...                                                ...
# 1146                                               NaN
# 1147                                               NaN
# 1148                                               NaN
# 1149                                               NaN
# 1150                                               NaN
#
#       240V Charge Time at 240 volts (hours)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1146                                    NaN
# 1147                                    NaN
# 1148                                    NaN
# 1149                                    NaN
# 1150                                    NaN
#
#       120V Charge time at 120 Volts (hours)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1146                                    NaN
# 1147                                    NaN
# 1148                                    NaN
# 1149                                    NaN
# 1150                                    NaN
#
#       PHEV Total Driving Range (rounded to nearest 10 miles)DISTANCE  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1146                                                NaN
# 1147                                                NaN
# 1148                                                NaN
# 1149                                                NaN
# 1150                                                NaN
#
#       City PHEV Composite MPGe Hwy PHEV Composite MPGe  \
# 0                          NaN                     NaN
# 1                          NaN                     NaN
# 2                          NaN                     NaN
# 3                          NaN                     NaN
# 4                          NaN                     NaN
# ...                        ...                     ...
# 1146                       NaN                     NaN
# 1147                       NaN                     NaN
# 1148                       NaN                     NaN
# 1149                       NaN                     NaN
# 1150                       NaN                     NaN
#
#      Comb PHEV Composite MPGe
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# ...                       ...
# 1146                      NaN
# 1147                      NaN
# 1148                      NaN
# 1149                      NaN
# 1150                      NaN
#
# [1151 rows x 162 columns]

# %%
#Drop the irrelevant columns from the later datasets. We will keep the same columns as in the 2015 dataset
for i in frames:
    for col in i.columns.tolist():
        if col not in columns:
            try:
                i.drop(col, axis = 1, inplace = True)
            except:
                print('Not successful at frame {0} and column {1}'.format(i, col))

# %%
df22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1151 entries, 0 to 1150
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Model Year                1151 non-null   int64
#  1   Mfr Name                  1151 non-null   object
#  2   Division                  1151 non-null   object
#  3   Carline                   1151 non-null   object
#  4   Engine Displacement       1151 non-null   float64
#  5   # Cylinders               1151 non-null   int64
#  6   Transmission              1151 non-null   object
#  7   City FE                   1151 non-null   int64
#  8   Highway FE                1151 non-null   int64
#  9   Combined FE               1151 non-null   int64
#  10  Air Aspiration Method     687 non-null    object
#  11  Transmission Description  1151 non-null   object
#  12  # Gears                   1151 non-null   int64
#  13  Drive Desc                1151 non-null   object
#  14  Carline Class Desc        1151 non-null   object
#  15  Release Date              1151 non-null   datetime64[ns]
#  16  City CO2                  1151 non-null   int64
#  17  Highway CO2               1151 non-null   int64
#  18  Combined CO2              1151 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(9), object(8)
# memory usage: 171.0+ KB

# %%
#Now we can aggregate the data, as we have dropped the unnecessarry columns from the dataframes and also use the same attribute names

df = pd.concat([df15, df16, df17, df18, df19, df20, df21, df22], ignore_index = True, axis = 0)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9248 entries, 0 to 9247
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Model Year                9248 non-null   int64
#  1   Mfr Name                  9248 non-null   object
#  2   Division                  9248 non-null   object
#  3   Carline                   9248 non-null   object
#  4   Engine Displacement       9248 non-null   float64
#  5   # Cylinders               9248 non-null   int64
#  6   Transmission              9248 non-null   object
#  7   City FE                   9248 non-null   int64
#  8   Highway FE                9248 non-null   int64
#  9   Combined FE               9248 non-null   int64
#  10  Air Aspiration Method     5517 non-null   object
#  11  Transmission Description  9248 non-null   object
#  12  # Gears                   9248 non-null   int64
#  13  Drive Desc                9248 non-null   object
#  14  Carline Class Desc        9248 non-null   object
#  15  Release Date              9248 non-null   datetime64[ns]
#  16  City CO2                  9248 non-null   int64
#  17  Highway CO2               9248 non-null   int64
#  18  Combined CO2              9248 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(9), object(8)
# memory usage: 1.3+ MB

# %%
#Now we want to rename the columns so it would match with the attribute names in the data warehouse
try:
    df.rename(columns = {"Model Year" : "Model_Year",
                        "Mfr Name" : "Mfr_Name",
                        "Engine Displacement" : "Engine_Displacement",
                        "# Cylinders" : "Cylinders",
                        "City FE" : "City_FE",
                        "Highway FE" : "Highway_FE",
                        "Combined FE" : "Combined_FE",
                        "Air Aspiration Method" : "Air_Aspiration_Method",
                        "Transmission Description" : "Trans_Desc",
                        "# Gears" : "Gears",
                        "Drive Desc" : "Drive_Desc",
                        "Carline Class Desc" : "Carline_Class_Desc",
                        "Release Date" : "Release_Date",
                        "City CO2" : "City_CO2",
                        "Highway CO2" : "Highway_CO2",
                        "Combined CO2" : "Combined_CO2"}, inplace = True)
except:
    print("Renaming failed. Check if column exists.")

#Let's verify if the renaming was successful
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9248 entries, 0 to 9247
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Model_Year             9248 non-null   int64
#  1   Mfr_Name               9248 non-null   object
#  2   Division               9248 non-null   object
#  3   Carline                9248 non-null   object
#  4   Engine_Displacement    9248 non-null   float64
#  5   Cylinders              9248 non-null   int64
#  6   Transmission           9248 non-null   object
#  7   City_FE                9248 non-null   int64
#  8   Highway_FE             9248 non-null   int64
#  9   Combined_FE            9248 non-null   int64
#  10  Air_Aspiration_Method  5517 non-null   object
#  11  Trans_Desc             9248 non-null   object
#  12  Gears                  9248 non-null   int64
#  13  Drive_Desc             9248 non-null   object
#  14  Carline_Class_Desc     9248 non-null   object
#  15  Release_Date           9248 non-null   datetime64[ns]
#  16  City_CO2               9248 non-null   int64
#  17  Highway_CO2            9248 non-null   int64
#  18  Combined_CO2           9248 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(9), object(8)
# memory usage: 1.3+ MB

# %% [markdown]
# ## 2. Drop Nan Values

# %%
#The only column with NA values is the Air_Aspiration_Method. However, these NA values are just an alias for "Naturally Aspirated". Therefore, we will replace the NA values with "Naturally Aspirated"

df.fillna(value = 'Naturally Aspirated', inplace = True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9248 entries, 0 to 9247
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Model_Year             9248 non-null   int64
#  1   Mfr_Name               9248 non-null   object
#  2   Division               9248 non-null   object
#  3   Carline                9248 non-null   object
#  4   Engine_Displacement    9248 non-null   float64
#  5   Cylinders              9248 non-null   int64
#  6   Transmission           9248 non-null   object
#  7   City_FE                9248 non-null   int64
#  8   Highway_FE             9248 non-null   int64
#  9   Combined_FE            9248 non-null   int64
#  10  Air_Aspiration_Method  9248 non-null   object
#  11  Trans_Desc             9248 non-null   object
#  12  Gears                  9248 non-null   int64
#  13  Drive_Desc             9248 non-null   object
#  14  Carline_Class_Desc     9248 non-null   object
#  15  Release_Date           9248 non-null   datetime64[ns]
#  16  City_CO2               9248 non-null   int64
#  17  Highway_CO2            9248 non-null   int64
#  18  Combined_CO2           9248 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(9), object(8)
# memory usage: 1.3+ MB

# %%
df.tail()
# Out:
#       Model_Year Mfr_Name                          Division  \
# 9243        2022   Toyota                            TOYOTA
# 9244        2022   Toyota                            TOYOTA
# 9245        2022   Toyota                            TOYOTA
# 9246        2022    Volvo  Volvo Cars of North America, LLC
# 9247        2022    Volvo  Volvo Cars of North America, LLC
#
#                              Carline  Engine_Displacement  Cylinders  \
# 9243           HIGHLANDER HYBRID AWD                  2.5          4
# 9244  HIGHLANDER HYBRID AWD LTD/PLAT                  2.5          4
# 9245                     SEQUOIA 4WD                  5.7          8
# 9246                     XC90 T5 AWD                  2.0          4
# 9247                     XC90 T6 AWD                  2.0          4
#
#      Transmission  City_FE  Highway_FE  Combined_FE Air_Aspiration_Method  \
# 9243  Auto(AV-S6)       35          35           35   Naturally Aspirated
# 9244  Auto(AV-S6)       35          34           35   Naturally Aspirated
# 9245     Auto(S6)       13          17           14   Naturally Aspirated
# 9246     Auto(S8)       20          28           23                    TC
# 9247     Auto(S8)       19          27           22                    TS
#
#                                              Trans_Desc  Gears  \
# 9243  Selectable Continuously Variable (e.g. CVT wit...      6
# 9244  Selectable Continuously Variable (e.g. CVT wit...      6
# 9245                                     Semi-Automatic      6
# 9246                                     Semi-Automatic      8
# 9247                                     Semi-Automatic      8
#
#                    Drive_Desc Carline_Class_Desc Release_Date  City_CO2  \
# 9243          All Wheel Drive   Standard SUV 4WD   2021-10-07       252
# 9244          All Wheel Drive   Standard SUV 4WD   2021-10-07       248
# 9245  Part-time 4-Wheel Drive   Standard SUV 4WD   2021-08-04       697
# 9246          All Wheel Drive   Standard SUV 4WD   2021-07-02       433
# 9247          All Wheel Drive   Standard SUV 4WD   2021-07-02       464
#
#       Highway_CO2  Combined_CO2
# 9243          256           254
# 9244          259           253
# 9245          522           618
# 9246          314           380
# 9247          333           405

# %% [markdown]
# ## 3. Clean the categorical values

# %% [markdown]
# ## a) Transmission column

# %%
print(df['Transmission'].unique())
# Out:
# ['Auto' 'Manual' 'Auto(AM6)' 'Auto(AM7)' 'Manual(M6)' 'Auto(AM-S6)'
#  'Auto(AM-S7)' 'Auto(S8)' 'Manual(M7)' 'Auto(AV-S7)' 'Auto(S6)' 'Auto(A7)'
#  'Auto(A9)' 'Manual(M5)' 'Auto(S7)' 'Auto(A6)' 'Auto(AV)' 'Auto(AM8)'
#  'Auto(AM-S8)' 'Auto(S9)' 'Auto(AV-S8)' 'Auto(AV-S6)' 'Auto(A4)'
#  'Auto(A8)' 'Auto(A5)' 'Auto(S5)' 'Auto(AM-S9)' 'Auto(S10)' 'Auto(A10)'
#  'Auto(AV-S10)' 'Auto(A1)' 'Auto(AV-S1)']

# %%
#Transform all the Transmission methods to only 2 types: auto and manual

auto = []
manual = []
for i in df['Transmission'].unique().tolist():
    if i.startswith("Auto"):
        auto.append(i)
    elif i.startswith("Manual"):
        manual.append(i)

df["Transmission"].replace(to_replace = auto, value = "Auto", inplace = True)
df["Transmission"].replace(to_replace = manual, value = "Manual", inplace = True)

print(df['Transmission'].unique())
# Out:
# ['Auto' 'Manual']

# %%
df.tail()
# Out:
#       Model_Year Mfr_Name                          Division  \
# 9243        2022   Toyota                            TOYOTA
# 9244        2022   Toyota                            TOYOTA
# 9245        2022   Toyota                            TOYOTA
# 9246        2022    Volvo  Volvo Cars of North America, LLC
# 9247        2022    Volvo  Volvo Cars of North America, LLC
#
#                              Carline  Engine_Displacement  Cylinders  \
# 9243           HIGHLANDER HYBRID AWD                  2.5          4
# 9244  HIGHLANDER HYBRID AWD LTD/PLAT                  2.5          4
# 9245                     SEQUOIA 4WD                  5.7          8
# 9246                     XC90 T5 AWD                  2.0          4
# 9247                     XC90 T6 AWD                  2.0          4
#
#      Transmission  City_FE  Highway_FE  Combined_FE Air_Aspiration_Method  \
# 9243         Auto       35          35           35   Naturally Aspirated
# 9244         Auto       35          34           35   Naturally Aspirated
# 9245         Auto       13          17           14   Naturally Aspirated
# 9246         Auto       20          28           23                    TC
# 9247         Auto       19          27           22                    TS
#
#                                              Trans_Desc  Gears  \
# 9243  Selectable Continuously Variable (e.g. CVT wit...      6
# 9244  Selectable Continuously Variable (e.g. CVT wit...      6
# 9245                                     Semi-Automatic      6
# 9246                                     Semi-Automatic      8
# 9247                                     Semi-Automatic      8
#
#                    Drive_Desc Carline_Class_Desc Release_Date  City_CO2  \
# 9243          All Wheel Drive   Standard SUV 4WD   2021-10-07       252
# 9244          All Wheel Drive   Standard SUV 4WD   2021-10-07       248
# 9245  Part-time 4-Wheel Drive   Standard SUV 4WD   2021-08-04       697
# 9246          All Wheel Drive   Standard SUV 4WD   2021-07-02       433
# 9247          All Wheel Drive   Standard SUV 4WD   2021-07-02       464
#
#       Highway_CO2  Combined_CO2
# 9243          256           254
# 9244          259           253
# 9245          522           618
# 9246          314           380
# 9247          333           405

# %% [markdown]
# ## b) Air Aspiration Column

# %%
#TC, SC, TS and OT signify "Turbocharged", "Supercharged", "Turbocharged+Supercharged" and "Other"

print(df["Air_Aspiration_Method"].unique())
# Out:
# ['Naturally Aspirated' 'Turbocharged' 'Supercharged'
#  'Turbocharged+Supercharged' 'TC' 'SC' 'TS' 'OT']

# %%
#We want to replace the TC, SC, TS and OT with their full description for readability

df["Air_Aspiration_Method"].replace(to_replace = ("TC", "SC", "TS", "OT"), value = ('Turbocharged', 'Supercharged', 'Turbocharged+Supercharged', 'Other'), inplace = True)

print(df["Air_Aspiration_Method"].unique())
# Out:
# ['Naturally Aspirated' 'Turbocharged' 'Supercharged'
#  'Turbocharged+Supercharged' 'Other']

# %% [markdown]
# ## c) Trans Desc column

# %%
# Let's check now the transmission description

print(df["Trans_Desc"].unique())
# Out:
# ['Automated Manual' 'Manual'
#  'Automated Manual- Selectable (e.g. Automated Manual with paddles)'
#  'Semi-Automatic' 'Automatic' 'Continuously Variable'
#  'Selectable Continuously Variable (e.g. CVT with paddles)']

# %%
# We want to remove the examples from the values in the transmission description column

df["Trans_Desc"].replace(to_replace = ("Automated Manual- Selectable (e.g. Automated Manual with paddles)", "Selectable Continuously Variable (e.g. CVT with paddles)"),
                        value = ("Automated Manual-Selectable", "Selectable Continuously Variable"), inplace = True)

print(df["Trans_Desc"].unique())
# Out:
# ['Automated Manual' 'Manual' 'Automated Manual-Selectable'
#  'Semi-Automatic' 'Automatic' 'Continuously Variable'
#  'Selectable Continuously Variable']

# %% [markdown]
# ## d) Drive Desc column

# %%
#Looking at the drive description column we can notice a specific values "d"

print(df["Drive_Desc"].unique())
# Out:
# ['2-Wheel Drive, Rear' 'All Wheel Drive' '2-Wheel Drive, Front' 'd'
#  '4-Wheel Drive' 'Part-time 4-Wheel Drive']

# %%
#There is one row containing this value "d", which can be safely dropped

df[df["Drive_Desc"] == "d"]
# Out:
#     Model_Year Mfr_Name Division      Carline  Engine_Displacement  Cylinders  \
# 62        2015  Porsche  Porsche  Boxster GTS                  3.4          6
#
#    Transmission  City_FE  Highway_FE  Combined_FE Air_Aspiration_Method  \
# 62       Manual       19          26           22   Naturally Aspirated
#
#    Trans_Desc  Gears Drive_Desc Carline_Class_Desc Release_Date  City_CO2  \
# 62     Manual      6          d        Two Seaters   2014-06-23       458
#
#     Highway_CO2  Combined_CO2
# 62          334           402

# %%
#Drop the specific row which contains value "d" in the "Drive_Desc" column

df.drop(df[df["Drive_Desc"] == "d"].index, axis = 0, inplace = True)

# %%
#Check if the drop was successful

print(df["Drive_Desc"].unique())
# Out:
# ['2-Wheel Drive, Rear' 'All Wheel Drive' '2-Wheel Drive, Front'
#  '4-Wheel Drive' 'Part-time 4-Wheel Drive']

# %% [markdown]
# # 4. Load the data

# %%
#Establish the connection between the datawarehouse and the python file

olap = create_engine('mysql+pymysql://root:''@localhost/marketing')
conn = olap.connect()

# %% [markdown]
# ## a) Engine data

# %%
#Create an engine dataframe that would be later loaded into the engine table in the data warehouse

df_engine = df[["Engine_Displacement", "Cylinders", "Air_Aspiration_Method"]]
df_engine.head()
# Out:
#    Engine_Displacement  Cylinders Air_Aspiration_Method
# 0                  6.0         12   Naturally Aspirated
# 1                  4.7          8   Naturally Aspirated
# 2                  4.7          8   Naturally Aspirated
# 3                  4.7          8   Naturally Aspirated
# 4                  4.7          8   Naturally Aspirated

# %%
#Select the unique combinations of columns in the engine dataframe

df_engine = df_engine.groupby(["Engine_Displacement", "Cylinders", "Air_Aspiration_Method"]).size().reset_index().rename(columns = {0 : "Count"})
df_engine
# Out:
#     Engine_Displacement  Cylinders Air_Aspiration_Method  Count
# 0                   0.9          3          Turbocharged      6
# 1                   1.0          3   Naturally Aspirated      2
# 2                   1.0          3          Turbocharged     12
# 3                   1.0          4          Turbocharged      1
# 4                   1.2          3   Naturally Aspirated     26
# ..                  ...        ...                   ...    ...
# 93                  6.7         12          Turbocharged     22
# 94                  6.8          8          Turbocharged      7
# 95                  7.0          8   Naturally Aspirated      1
# 96                  8.0         16          Turbocharged     10
# 97                  8.4         10   Naturally Aspirated      2
#
# [98 rows x 4 columns]

# %%
#We will drop the Count column as we do not need it in the Engine table

df_engine.drop("Count", axis = 1, inplace = True)
df_engine
# Out:
#     Engine_Displacement  Cylinders Air_Aspiration_Method
# 0                   0.9          3          Turbocharged
# 1                   1.0          3   Naturally Aspirated
# 2                   1.0          3          Turbocharged
# 3                   1.0          4          Turbocharged
# 4                   1.2          3   Naturally Aspirated
# ..                  ...        ...                   ...
# 93                  6.7         12          Turbocharged
# 94                  6.8          8          Turbocharged
# 95                  7.0          8   Naturally Aspirated
# 96                  8.0         16          Turbocharged
# 97                  8.4         10   Naturally Aspirated
#
# [98 rows x 3 columns]

# %%
# Lastly, we will change the index numbers so they would start from 1 to 130 and match the indexes from the engine table in the data warehouse

df_engine.index += 1
df_engine
# Out:
#     Engine_Displacement  Cylinders Air_Aspiration_Method
# 1                   0.9          3          Turbocharged
# 2                   1.0          3   Naturally Aspirated
# 3                   1.0          3          Turbocharged
# 4                   1.0          4          Turbocharged
# 5                   1.2          3   Naturally Aspirated
# ..                  ...        ...                   ...
# 94                  6.7         12          Turbocharged
# 95                  6.8          8          Turbocharged
# 96                  7.0          8   Naturally Aspirated
# 97                  8.0         16          Turbocharged
# 98                  8.4         10   Naturally Aspirated
#
# [98 rows x 3 columns]

# %%
#Load it to the engine table in the data warehouse

df_engine.to_sql("engine", conn, if_exists = "append", index = False)
# Out:
# 98

# %% [markdown]
# ## b) Transmission Data

# %%
#Get the data for the Transmission table

df_trans = df[['Transmission', 'Trans_Desc', 'Gears']]
df_trans
# Out:
#      Transmission                        Trans_Desc  Gears
# 0            Auto                  Automated Manual      7
# 1            Auto                  Automated Manual      7
# 2          Manual                            Manual      6
# 3            Auto                  Automated Manual      7
# 4          Manual                            Manual      6
# ...           ...                               ...    ...
# 9243         Auto  Selectable Continuously Variable      6
# 9244         Auto  Selectable Continuously Variable      6
# 9245         Auto                    Semi-Automatic      6
# 9246         Auto                    Semi-Automatic      8
# 9247         Auto                    Semi-Automatic      8
#
# [9247 rows x 3 columns]

# %%
#Get unique combinations of the columns

df_trans = df_trans.groupby(['Transmission', 'Trans_Desc', 'Gears']).size().reset_index().rename(columns = {0 : "Counts"})
df_trans
# Out:
#    Transmission                        Trans_Desc  Gears  Counts
# 0          Auto                  Automated Manual      5       2
# 1          Auto                  Automated Manual      6      65
# 2          Auto                  Automated Manual      7     220
# 3          Auto                  Automated Manual      8      24
# 4          Auto       Automated Manual-Selectable      6     100
# 5          Auto       Automated Manual-Selectable      7     523
# 6          Auto       Automated Manual-Selectable      8     157
# 7          Auto       Automated Manual-Selectable      9       6
# 8          Auto                         Automatic      1       2
# 9          Auto                         Automatic      4      18
# 10         Auto                         Automatic      5      30
# 11         Auto                         Automatic      6     569
# 12         Auto                         Automatic      7     195
# 13         Auto                         Automatic      8     619
# 14         Auto                         Automatic      9     567
# 15         Auto                         Automatic     10     218
# 16         Auto             Continuously Variable      1     340
# 17         Auto  Selectable Continuously Variable      1      12
# 18         Auto  Selectable Continuously Variable      6     163
# 19         Auto  Selectable Continuously Variable      7     159
# 20         Auto  Selectable Continuously Variable      8      98
# 21         Auto  Selectable Continuously Variable     10      36
# 22         Auto                    Semi-Automatic      5      23
# 23         Auto                    Semi-Automatic      6    1266
# 24         Auto                    Semi-Automatic      7     162
# 25         Auto                    Semi-Automatic      8    1983
# 26         Auto                    Semi-Automatic      9     171
# 27         Auto                    Semi-Automatic     10     373
# 28       Manual                            Manual      5     152
# 29       Manual                            Manual      6     881
# 30       Manual                            Manual      7     113

# %%
# Drop the Counts column and increment indexes is 1

df_trans.drop('Counts', axis = 1, inplace = True)
df_trans.index += 1

df_trans
# Out:
#    Transmission                        Trans_Desc  Gears
# 1          Auto                  Automated Manual      5
# 2          Auto                  Automated Manual      6
# 3          Auto                  Automated Manual      7
# 4          Auto                  Automated Manual      8
# 5          Auto       Automated Manual-Selectable      6
# 6          Auto       Automated Manual-Selectable      7
# 7          Auto       Automated Manual-Selectable      8
# 8          Auto       Automated Manual-Selectable      9
# 9          Auto                         Automatic      1
# 10         Auto                         Automatic      4
# 11         Auto                         Automatic      5
# 12         Auto                         Automatic      6
# 13         Auto                         Automatic      7
# 14         Auto                         Automatic      8
# 15         Auto                         Automatic      9
# 16         Auto                         Automatic     10
# 17         Auto             Continuously Variable      1
# 18         Auto  Selectable Continuously Variable      1
# 19         Auto  Selectable Continuously Variable      6
# 20         Auto  Selectable Continuously Variable      7
# 21         Auto  Selectable Continuously Variable      8
# 22         Auto  Selectable Continuously Variable     10
# 23         Auto                    Semi-Automatic      5
# 24         Auto                    Semi-Automatic      6
# 25         Auto                    Semi-Automatic      7
# 26         Auto                    Semi-Automatic      8
# 27         Auto                    Semi-Automatic      9
# 28         Auto                    Semi-Automatic     10
# 29       Manual                            Manual      5
# 30       Manual                            Manual      6
# 31       Manual                            Manual      7

# %%
# Load the data into the Transmission table in the data warehouse

df_trans.to_sql('transmission', conn, if_exists = 'append', index = False)
# Out:
# 31

# %% [markdown]
# ## c) Car Data

# %%
#Select the data for the Car table in the data warehouse

df_car = df[["Model_Year", "Mfr_Name", "Division", "Carline", "Drive_Desc", "Carline_Class_Desc", "Release_Date"]]
df_car
# Out:
#       Model_Year      Mfr_Name                          Division  \
# 0           2015  aston martin          Aston Martin Lagonda Ltd
# 1           2015  aston martin          Aston Martin Lagonda Ltd
# 2           2015  aston martin          Aston Martin Lagonda Ltd
# 3           2015  aston martin          Aston Martin Lagonda Ltd
# 4           2015  aston martin          Aston Martin Lagonda Ltd
# ...          ...           ...                               ...
# 9243        2022        Toyota                            TOYOTA
# 9244        2022        Toyota                            TOYOTA
# 9245        2022        Toyota                            TOYOTA
# 9246        2022         Volvo  Volvo Cars of North America, LLC
# 9247        2022         Volvo  Volvo Cars of North America, LLC
#
#                              Carline               Drive_Desc  \
# 0                      V12 Vantage S      2-Wheel Drive, Rear
# 1                         V8 Vantage      2-Wheel Drive, Rear
# 2                         V8 Vantage      2-Wheel Drive, Rear
# 3                       V8 Vantage S      2-Wheel Drive, Rear
# 4                       V8 Vantage S      2-Wheel Drive, Rear
# ...                              ...                      ...
# 9243           HIGHLANDER HYBRID AWD          All Wheel Drive
# 9244  HIGHLANDER HYBRID AWD LTD/PLAT          All Wheel Drive
# 9245                     SEQUOIA 4WD  Part-time 4-Wheel Drive
# 9246                     XC90 T5 AWD          All Wheel Drive
# 9247                     XC90 T6 AWD          All Wheel Drive
#
#      Carline_Class_Desc Release_Date
# 0           Two Seaters   2014-01-20
# 1           Two Seaters   2014-05-19
# 2           Two Seaters   2014-05-19
# 3           Two Seaters   2014-05-19
# 4           Two Seaters   2014-05-19
# ...                 ...          ...
# 9243   Standard SUV 4WD   2021-10-07
# 9244   Standard SUV 4WD   2021-10-07
# 9245   Standard SUV 4WD   2021-08-04
# 9246   Standard SUV 4WD   2021-07-02
# 9247   Standard SUV 4WD   2021-07-02
#
# [9247 rows x 7 columns]

# %%
#Find all the possible combinations of columns for the car table

df_car = df_car.groupby(["Model_Year", "Mfr_Name", "Division", "Carline", "Drive_Desc", "Carline_Class_Desc", "Release_Date"]).size().reset_index().rename(columns = {0 : "Counts"})
df_car
# Out:
#       Model_Year      Mfr_Name                  Division      Carline  \
# 0           2015           BMW                       BMW         228i
# 1           2015           BMW                       BMW         228i
# 2           2015           BMW                       BMW  228i xDrive
# 3           2015           BMW                       BMW         320i
# 4           2015           BMW                       BMW  320i xDrive
# ...          ...           ...                       ...          ...
# 7064        2022  aston martin  Aston Martin Lagonda Ltd     DB11 V12
# 7065        2022  aston martin  Aston Martin Lagonda Ltd      DB11 V8
# 7066        2022  aston martin  Aston Martin Lagonda Ltd          DBS
# 7067        2022  aston martin  Aston Martin Lagonda Ltd       DBX V8
# 7068        2022  aston martin  Aston Martin Lagonda Ltd   Vantage V8
#
#                Drive_Desc Carline_Class_Desc Release_Date  Counts
# 0     2-Wheel Drive, Rear    Subcompact Cars   2014-07-15       1
# 1     2-Wheel Drive, Rear    Subcompact Cars   2014-07-16       1
# 2         All Wheel Drive    Subcompact Cars   2014-07-16       1
# 3     2-Wheel Drive, Rear       Compact Cars   2014-07-14       1
# 4         All Wheel Drive       Compact Cars   2014-07-16       1
# ...                   ...                ...          ...     ...
# 7064  2-Wheel Drive, Rear   Minicompact Cars   2021-11-29       1
# 7065  2-Wheel Drive, Rear   Minicompact Cars   2021-10-25       1
# 7066  2-Wheel Drive, Rear   Minicompact Cars   2021-11-29       1
# 7067        4-Wheel Drive   Standard SUV 4WD   2021-10-25       1
# 7068  2-Wheel Drive, Rear        Two Seaters   2021-10-25       1
#
# [7069 rows x 8 columns]

# %%
#Increment the index by 1 so it would match the index from the car table in the data warehouse and also drop the Counts column

df_car.index += 1
df_car.drop('Counts', axis = 1, inplace = True)
df_car
# Out:
#       Model_Year      Mfr_Name                  Division      Carline  \
# 1           2015           BMW                       BMW         228i
# 2           2015           BMW                       BMW         228i
# 3           2015           BMW                       BMW  228i xDrive
# 4           2015           BMW                       BMW         320i
# 5           2015           BMW                       BMW  320i xDrive
# ...          ...           ...                       ...          ...
# 7065        2022  aston martin  Aston Martin Lagonda Ltd     DB11 V12
# 7066        2022  aston martin  Aston Martin Lagonda Ltd      DB11 V8
# 7067        2022  aston martin  Aston Martin Lagonda Ltd          DBS
# 7068        2022  aston martin  Aston Martin Lagonda Ltd       DBX V8
# 7069        2022  aston martin  Aston Martin Lagonda Ltd   Vantage V8
#
#                Drive_Desc Carline_Class_Desc Release_Date
# 1     2-Wheel Drive, Rear    Subcompact Cars   2014-07-15
# 2     2-Wheel Drive, Rear    Subcompact Cars   2014-07-16
# 3         All Wheel Drive    Subcompact Cars   2014-07-16
# 4     2-Wheel Drive, Rear       Compact Cars   2014-07-14
# 5         All Wheel Drive       Compact Cars   2014-07-16
# ...                   ...                ...          ...
# 7065  2-Wheel Drive, Rear   Minicompact Cars   2021-11-29
# 7066  2-Wheel Drive, Rear   Minicompact Cars   2021-10-25
# 7067  2-Wheel Drive, Rear   Minicompact Cars   2021-11-29
# 7068        4-Wheel Drive   Standard SUV 4WD   2021-10-25
# 7069  2-Wheel Drive, Rear        Two Seaters   2021-10-25
#
# [7069 rows x 7 columns]

# %%
df_car.to_sql('car', conn, if_exists = 'append', index = False)
# Out:
# 7069

# %% [markdown]
# ## d) FE_Facts data

# %%
#First we will drop from the dataframe the columns which cannot be found in the fact table

df_fact = df.copy()
df_fact.drop(["Model_Year", "Mfr_Name", "Division", "Carline", "Drive_Desc", "Carline_Class_Desc", "Release_Date",
               'Transmission', 'Trans_Desc', 'Gears', "Engine_Displacement", "Cylinders", "Air_Aspiration_Method"], axis = 1, inplace = True)
df_fact
# Out:
#       City_FE  Highway_FE  Combined_FE  City_CO2  Highway_CO2  Combined_CO2
# 0          12          18           14       742          488           628
# 1          14          21           16       655          426           552
# 2          13          19           15       681          461           582
# 3          14          21           16       655          426           552
# 4          13          19           15       681          461           582
# ...       ...         ...          ...       ...          ...           ...
# 9243       35          35           35       252          256           254
# 9244       35          34           35       248          259           253
# 9245       13          17           14       697          522           618
# 9246       20          28           23       433          314           380
# 9247       19          27           22       464          333           405
#
# [9247 rows x 6 columns]

# %%
# Now for each row in the initial dataframe, we will find the respective indices in the dimensional tables and add them in lists 

car_idx = []
engine_idx = []
trans_idx = []
for idx, row in df.iterrows():

    temp = df_car[df_car["Model_Year"] == row["Model_Year"]]
    temp = temp[temp["Mfr_Name"] == row["Mfr_Name"]]
    temp = temp[temp["Division"] == row["Division"]]
    temp = temp[temp["Carline"] == row["Carline"]]
    temp = temp[temp["Drive_Desc"] == row["Drive_Desc"]]
    temp = temp[temp["Carline_Class_Desc"] == row["Carline_Class_Desc"]]
    temp = temp[temp["Release_Date"] == row["Release_Date"]]
    car_idx.extend(temp.index.values)


    temp = df_engine[df_engine["Engine_Displacement"] == row["Engine_Displacement"]]
    temp = temp[temp["Cylinders"] == row["Cylinders"]]
    temp = temp[temp["Air_Aspiration_Method"] == row["Air_Aspiration_Method"]]
    engine_idx.extend(temp.index.values)

    temp = df_trans[df_trans["Transmission"] == row["Transmission"]]
    temp = temp[temp["Trans_Desc"] == row["Trans_Desc"]]
    temp = temp[temp["Gears"] == row["Gears"]]
    trans_idx.extend(temp.index.values)

# %%
# Append the indeces to the fact table

df_fact["Model_ID"] = car_idx
df_fact["Engine_ID"] = engine_idx
df_fact["Trans_ID"] = trans_idx

df_fact
# Out:
#       City_FE  Highway_FE  Combined_FE  City_CO2  Highway_CO2  Combined_CO2  \
# 0          12          18           14       742          488           628
# 1          14          21           16       655          426           552
# 2          13          19           15       681          461           582
# 3          14          21           16       655          426           552
# 4          13          19           15       681          461           582
# ...       ...         ...          ...       ...          ...           ...
# 9243       35          35           35       252          256           254
# 9244       35          34           35       248          259           253
# 9245       13          17           14       697          522           618
# 9246       20          28           23       433          314           380
# 9247       19          27           22       464          333           405
#
#       Model_ID  Engine_ID  Trans_ID
# 0          505         85         3
# 1          506         67         3
# 2          506         67        30
# 3          507         67         3
# 4          507         67        30
# ...        ...        ...       ...
# 9243      6943         27        19
# 9244      6944         27        19
# 9245      6954         82        24
# 9246      7063         20        26
# 9247      7064         21        26
#
# [9247 rows x 9 columns]

# %%
# Load the data to the fact table in the data warehouse

df_fact.to_sql('fe_facts', conn, if_exists = 'append', index = False)
# Out:
# 9247
